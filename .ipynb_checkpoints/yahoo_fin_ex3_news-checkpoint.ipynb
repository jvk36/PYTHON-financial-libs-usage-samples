# %%
from yahoo_fin import news
 
news.get_yf_rss("nflx")
# Out:
# [{'summary': "Two of the more formidable players in the industry, Netflix (NASDAQ: NFLX) and Walt Disney's (NYSE: DIS) Disney+, each have hundreds of millions of subscribers today.  In its most recent period (the third quarter of 2022, ended Sept. 30), Netflix generated average revenue per user (ARPU) of $11.84, which was much higher than the ARPU of $3.91 for Disney+.  The low ARPU at Disney is contributing to wide operating losses: $1.5 billion in the latest fiscal quarter in the company's direct-to-consumer (DTC) segment.",
#   'summary_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://feeds.finance.yahoo.com/rss/2.0/headline?s=nflx&region=US&lang=en-US',
# ...
