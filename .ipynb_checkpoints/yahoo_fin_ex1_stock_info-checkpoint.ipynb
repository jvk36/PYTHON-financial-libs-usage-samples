# %%
import yahoo_fin.stock_info as si

si.get_analysts_info('nflx')
# Out:
# {'Earnings Estimate':   Earnings Estimate  Current Qtr. (Dec 2022)  Next Qtr. (Mar 2023)  \
#  0   No. of Analysts                    30.00                 21.00
#  1     Avg. Estimate                     0.42                  2.96
#  2      Low Estimate                     0.30                  2.20
#  3     High Estimate                     1.02                  3.65
#  4      Year Ago EPS                     1.33                  3.53
#
#     Current Year (2022)  Next Year (2023)
#  0                33.00             34.00
#  1                10.35             10.52
#  2                10.10              8.51
#  3                11.97             13.01
#  4                11.24             10.35  ,
#  'Revenue Estimate':           Revenue Estimate Current Qtr. (Dec 2022) Next Qtr. (Mar 2023)  \
#  0          No. of Analysts                      28                   17
#  1            Avg. Estimate                   7.81B                8.11B
# ...

# %%
# get yearly data
si.get_balance_sheet('nflx')
 
# get quarterly data
si.get_balance_sheet('nflx', yearly = False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# get yearly data
si.get_cash_flow('nflx')
 
# get quarterly data
si.get_cash_flow('nflx', yearly = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9e360d00fc6a> in <module>
#       1 # get yearly data
# ----> 2 si.get_cash_flow('nflx')
#       3
#       4 # get quarterly data
#       5 si.get_cash_flow('nflx', yearly = False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_cash_flow(ticker, yearly)
#     465
#     466     if yearly:
# --> 467         temp = json_info["cashflowStatementHistory"]["cashflowStatements"]
#     468     else:
#     469         temp = json_info["cashflowStatementHistoryQuarterly"]["cashflowStatements"]
#
# TypeError: string indices must be integers

# %%
si.get_company_info("aapl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-d0638b9526d8> in <module>
# ----> 1 si.get_company_info("aapl")
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_company_info(ticker)
#    1013     site = f"https://finance.yahoo.com/quote/{ticker}/profile?p={ticker}"
#    1014     json_info = _parse_json(site)
# -> 1015     json_info = json_info["assetProfile"]
#    1016     info_frame = pd.DataFrame.from_dict(json_info,
#    1017                                         orient="index",
#
# TypeError: string indices must be integers

# %%
si.get_company_officers("aapl")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-a9b6aff2ca40> in <module>
# ----> 1 si.get_company_officers("aapl")
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_company_officers(ticker)
#    1029     site = f"https://finance.yahoo.com/quote/{ticker}/profile?p={ticker}"
#    1030     json_info = _parse_json(site)
# -> 1031     json_info = json_info["assetProfile"]["companyOfficers"]
#    1032     info_frame = pd.DataFrame.from_dict(json_info)
#    1033     info_frame = info_frame.set_index("name")
#
# TypeError: string indices must be integers

# %%
si.get_currencies()
# Out:
#       Symbol     Name  Last Price   Change % Change  52 Week Range  Day Chart
# 0   EURUSD=X  EUR/USD      1.0574  -0.0060   -0.56%            NaN        NaN
# 1      JPY=X  USD/JPY    136.6900  -1.0500   -0.76%            NaN        NaN
# 2   GBPUSD=X  GBP/USD      1.2161  -0.0021   -0.17%            NaN        NaN
# 3   AUDUSD=X  AUD/USD      0.6686  -0.0022   -0.32%            NaN        NaN
# 4   NZDUSD=X  NZD/USD      0.6378   0.0032   +0.51%            NaN        NaN
# 5   EURJPY=X  EUR/JPY    144.7320  -1.6980   -1.16%            NaN        NaN
# 6   GBPJPY=X  GBP/JPY    165.9950  -1.7670   -1.05%            NaN        NaN
# 7   EURGBP=X  EUR/GBP      0.8719  -0.0000   -0.00%            NaN        NaN
# 8   EURCAD=X  EUR/CAD      1.4498  -0.0020   -0.14%            NaN        NaN
# 9   EURSEK=X  EUR/SEK     11.0148   0.0280   +0.25%            NaN        NaN
# 10  EURCHF=X  EUR/CHF      0.9883   0.0022   +0.23%            NaN        NaN
# ...

# %%
msft_data = si.get_data('msft')
msft_data
# Out:
#                   open        high         low       close    adjclose  \
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060809
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062980
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.064067
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062437
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061351
# ...                ...         ...         ...         ...         ...
# 2022-12-12  247.449997  252.539993  247.169998  252.509995  252.509995
# 2022-12-13  261.690002  263.920013  253.070007  256.920013  256.920013
# 2022-12-14  257.130005  262.589996  254.309998  257.220001  257.220001
# 2022-12-15  253.720001  254.199997  247.339996  249.009995  249.009995
# 2022-12-16  248.550003  249.839996  243.509995  244.690002  244.690002
#
#                 volume ticker
# 1986-03-13  1031788800   MSFT
# 1986-03-14   308160000   MSFT
# ...

# %%
from1999 = si.get_data('msft' , start_date = '01/01/1999')
few_days = si.get_data('msft' , start_date = '01/01/1999' , end_date = '01/10/1999')
few_days
# Out:
#                  open      high        low     close   adjclose    volume  \
# 1999-01-04  34.902344  36.31250  34.843750  35.25000  22.047489  69305200
# 1999-01-05  35.468750  37.00000  35.359375  36.62500  22.907497  64281600
# 1999-01-06  37.375000  37.87500  36.687500  37.81250  23.650240  69064800
# 1999-01-07  37.437500  37.65625  37.062500  37.62500  23.532963  51150400
# 1999-01-08  38.046875  38.12500  36.750000  37.46875  23.435228  50244800
#
#            ticker
# 1999-01-04   MSFT
# 1999-01-05   MSFT
# 1999-01-06   MSFT
# 1999-01-07   MSFT
# 1999-01-08   MSFT

# %%
weekly_data = si.get_data("msft", interval = "1wk")
 
monthly_data = si.get_data("msft", interval = "1mo")
monthly_data
# Out:
#                   open        high         low       close    adjclose  \
# 1986-04-01    0.095486    0.121962    0.092882    0.111979    0.070038
# 1986-05-01    0.111979    0.123264    0.107639    0.121528    0.076011
# 1986-06-01    0.121528    0.121528    0.102431    0.106771    0.066781
# 1986-07-01    0.106771    0.109375    0.090278    0.098958    0.061894
# 1986-08-01    0.098958    0.106771    0.094618    0.098958    0.061894
# ...                ...         ...         ...         ...         ...
# 2022-09-01  258.869995  267.450012  232.729996  232.899994  232.245483
# 2022-10-01  235.410004  251.039993  219.130005  232.130005  231.477661
# 2022-11-01  234.600006  255.330002  213.429993  255.139999  254.422989
# 2022-12-01  253.869995  263.920013  242.210007  244.690002  244.690002
# 2022-12-16  248.550003  249.820007  243.550003  244.690002  244.690002
#
#                volume ticker
# 1986-04-01  547142400   MSFT
# 1986-05-01  333446400   MSFT
# ...

# %%
si.get_day_gainers()
# Out:
#    Symbol                                              Name  Price (Intraday)  \
# 0    MAXR                           Maxar Technologies Inc.           51.9300
# 1    EXAS                        Exact Sciences Corporation           51.9200
# 2     TAL                               TAL Education Group            7.4600
# 3    NTRA                                      Natera, Inc.           43.3200
# 4   CURLF                           Curaleaf Holdings, Inc.            5.1600
# 5   BKRIF                         Bank of Ireland Group plc            8.8000
# 6   GTBIF                       Green Thumb Industries Inc.            9.8300
# 7   FNMAK             Federal National Mortgage Association            3.1000
# 8   CAIXY                                   CaixaBank, S.A.            1.2100
# 9   DIDIY                                  DiDi Global Inc.            3.6400
# 10   AKRO                          Akero Therapeutics, Inc.           46.9500
# ...

# %%
si.get_day_losers()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d174920b474a> in <module>
# ----> 1 si.get_day_losers()
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_day_losers(count)
#     623 def get_day_losers(count: int = 100):
#     624
# --> 625     return _raw_get_daily_info(f"https://finance.yahoo.com/losers?offset=0&count={count}")
#     626
#     627
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in _raw_get_daily_info(site)
#     604
#     605         if type(df[field][0]) == str:
# --> 606             df[field] = df[field].map(_convert_to_numeric)
#     607
#     608     session.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# ...

# %%
si.get_day_most_active()
# Out:
#    Symbol                          Name  Price (Intraday)  Change  % Change  \
# 0     WBD  Warner Bros. Discovery, Inc.              9.91   -0.09     -0.90
# 1    AMZN              Amazon.com, Inc.             87.86   -0.59     -0.67
# 2       F            Ford Motor Company             12.12   -0.91     -6.98
# 3    TSLA                   Tesla, Inc.            150.23   -7.44     -4.72
# 4    AAPL                    Apple Inc.            134.51   -1.99     -1.46
# ..    ...                           ...               ...     ...       ...
# 95   AGNC         AGNC Investment Corp.             10.14   -0.10     -0.98
# 96   AFRM         Affirm Holdings, Inc.             10.12   -0.25     -2.41
# 97    NWL            Newell Brands Inc.             13.07   -0.13     -0.98
# 98   ABBV                   AbbVie Inc.            160.48   -2.62     -1.61
# 99    JNJ             Johnson & Johnson            175.67   -1.82     -1.03
#
# ...

# %%
# get all historical dividend data
si.get_dividends("msft")
 
# dividends from 2010 onward
si.get_dividends("msft", "01-01-2010")
# Out:
#             dividend ticker
# 2010-02-16      0.13   MSFT
# 2010-05-18      0.13   MSFT
# 2010-08-17      0.13   MSFT
# 2010-11-16      0.16   MSFT
# 2011-02-15      0.16   MSFT
# 2011-05-17      0.16   MSFT
# 2011-08-16      0.16   MSFT
# 2011-11-15      0.20   MSFT
# 2012-02-14      0.20   MSFT
# 2012-05-15      0.20   MSFT
# 2012-08-14      0.20   MSFT
# 2012-11-13      0.23   MSFT
# 2013-02-19      0.23   MSFT
# 2013-05-14      0.23   MSFT
# 2013-08-13      0.23   MSFT
# 2013-11-19      0.28   MSFT
# 2014-02-18      0.28   MSFT
# 2014-05-13      0.28   MSFT
# 2014-08-19      0.28   MSFT
# 2014-11-18      0.31   MSFT
# 2015-02-17      0.31   MSFT
# 2015-05-19      0.31   MSFT
# 2015-08-18      0.31   MSFT
# 2015-11-17      0.36   MSFT
# 2016-02-16      0.36   MSFT
# 2016-05-17      0.36   MSFT
# 2016-08-16      0.36   MSFT
# 2016-11-15      0.39   MSFT
# 2017-02-14      0.39   MSFT
# 2017-05-16      0.39   MSFT
# 2017-08-15      0.39   MSFT
# 2017-11-15      0.42   MSFT
# ...

# %%
si.get_earnings('nflx')
# Out:
# {'quarterly_results': Empty DataFrame
#  Columns: []
#  Index: [],
#  'yearly_revenue_earnings': Empty DataFrame
#  Columns: []
#  Index: [],
#  'quarterly_revenue_earnings': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
si.get_earnings_for_date('02/08/2021')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-5f9a85663292> in <module>
# ----> 1 si.get_earnings_for_date('02/08/2021')
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_earnings_for_date(date, offset, count)
#     862     stores = result['context']['dispatcher']['stores']
#     863
# --> 864     earnings_count = stores['ScreenerCriteriaStore']['meta']['total']
#     865
#     866     new_offset = offset + 100
#
# TypeError: string indices must be integers

# %%
hist = si.get_earnings_history('msft')
 
hist[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-dd162f9317ae> in <module>
# ----> 1 hist = si.get_earnings_history('msft')
#       2
#       3 hist[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_earnings_history(ticker)
#     836         result = _parse_earnings_json(url)
#     837
# --> 838         return result["context"]["dispatcher"]["stores"]["ScreenerResultsStore"]["results"]["rows"]
#     839
#     840
#
# TypeError: string indices must be integers

# %%
si.get_earnings_in_date_range('02/08/2021', '02/12/2021')
# Out:
# []

# %%
# get both yearly and quarterly info
si.get_financials('nflx')
 
# get only yearly data
si.get_financials('nflx', yearly = True, quarterly = False)
 
# get only quarterly data
si.get_financials('nflx', yearly = False, quarterly = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-105b88110e23> in <module>
#       1 # get both yearly and quarterly info
# ----> 2 si.get_financials('nflx')
#       3
#       4 # get only yearly data
#       5 si.get_financials('nflx', yearly = True, quarterly = False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_financials(ticker, yearly, quarterly)
#     495     if yearly:
#     496
# --> 497         temp = json_info["incomeStatementHistory"]["incomeStatementHistory"]
#     498         table = _parse_table(temp)
#     499         result["yearly_income_statement"] = table
#
# TypeError: string indices must be integers

# %%
si.get_futures()
# Out:
#    Symbol                             Name    Last Price  Market Time  \
# 0    ES=F            E-Mini S&P 500 Mar 23   3872.000000   4:59PM EST
# 1    YM=F  Mini Dow Jones Indus.-$5 Mar 23  32862.000000   9:29AM EST
# 2    NQ=F                Nasdaq 100 Mar 23  11320.000000   4:59PM EST
# 3   RTY=F  E-mini Russell 2000 Index Futur   1770.800000   4:59PM EST
# 4    ZB=F  U.S. Treasury Bond Futures,Mar-    131.093750   4:59PM EST
# 5    ZN=F  10-Year T-Note Futures,Mar-2023    114.750000   4:59PM EST
# 6    ZF=F  Five-Year US Treasury Note Futu    109.468750   4:59PM EST
# 7    ZT=F   2-Year T-Note Futures,Mar-2023    103.078125   4:59PM EST
# 8    GC=F                             Gold   1803.000000   4:59PM EST
# 9   MGC=F      Micro Gold Futures,Feb-2023   1802.600000   4:59PM EST
# 10   SI=F                           Silver     23.410000   4:59PM EST
# 11  SIL=F    Micro Silver Futures,Mar-2023     23.420000   4:59PM EST
# ...

# %%
si.get_holders('nflx')
# Out:
# {'Major Holders':         0                                      1
#  0   1.44%        % of Shares Held by All Insider
#  1  80.05%       % of Shares Held by Institutions
#  2  81.22%        % of Float Held by Institutions
#  3    2351  Number of Institutions Holding Shares,
#  'Direct Holders (Forms 3 and 4)':                               Holder    Shares Date Reported  % Out  \
#  0         Vanguard Group, Inc. (The)  35119551  Sep 29, 2022  7.89%
#  1                     Blackrock Inc.  28037016  Sep 29, 2022  6.30%
#  2                           FMR, LLC  20032104  Sep 29, 2022  4.50%
#  3           State Street Corporation  16503223  Sep 29, 2022  3.71%
#  4  Capital Research Global Investors  15343400  Sep 29, 2022  3.45%
#  5    Capital International Investors  14358964  Sep 29, 2022  3.23%
#  6            Capital World Investors  12794791  Sep 29, 2022  2.88%
#  7      Price (T.Rowe) Associates Inc  11405142  Sep 29, 2022  2.56%
# ...

# %%
# get yearly data
si.get_income_statement('nflx')
 
# get quarterly data
si.get_income_statement('nflx', yearly = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-86e401df4ad5> in <module>
#       1 # get yearly data
# ----> 2 si.get_income_statement('nflx')
#       3
#       4 # get quarterly data
#       5 si.get_income_statement('nflx', yearly = False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_income_statement(ticker, yearly)
#     420
#     421     if yearly:
# --> 422         temp = json_info["incomeStatementHistory"]["incomeStatementHistory"]
#     423     else:
#     424         temp = json_info["incomeStatementHistoryQuarterly"]["incomeStatementHistory"]
#
# TypeError: string indices must be integers

# %%
si.get_live_price('nflx')
# Out:
# 290.7099914550781

# %%
si.get_market_status()
# Out:
# 'CLOSED'

# %%
si.get_next_earnings_date('nflx')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-b37e50c383a6> in <module>
# ----> 1 si.get_next_earnings_date('nflx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_next_earnings_date(ticker)
#     821     parsed_result = _parse_earnings_json(new_url)
#     822
# --> 823     temp = parsed_result['context']['dispatcher']['stores']['QuoteSummaryStore']['calendarEvents']['earnings']['earningsDate'][0]['raw']
#     824
#     825     return datetime.datetime.fromtimestamp(temp)
#
# TypeError: string indices must be integers

# %%
si.get_premarket_price('nflx')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-ca958a95403e> in <module>
# ----> 1 si.get_premarket_price('nflx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\yahoo_fin\stock_info.py in get_premarket_price(ticker)
#     988         return quote_data["preMarketPrice"]
#     989
# --> 990     raise AssertionError("Premarket price not currently available.")
#     991
#     992 def get_postmarket_price(ticker):
#
# AssertionError: Premarket price not currently available.

# %%
si.get_postmarket_price('nflx')
# Out:
# 290.21

# %%
si.get_quote_data('nflx')
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'currency': 'USD',
#  'marketState': 'CLOSED',
#  'regularMarketChangePercent': 0.10329803,
#  'regularMarketPrice': 290.71,
#  'exchange': 'NMS',
#  'shortName': 'Netflix, Inc.',
#  'longName': 'Netflix, Inc.',
#  'messageBoardId': 'finmb_32012',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'postMarketChangePercent': -0.171993,
#  'postMarketTime': 1671238772,
#  'postMarketPrice': 290.21,
#  'postMarketChange': -0.5,
#  'regularMarketChange': 0.2999878,
#  'regularMarketTime': 1671224406,
#  'regularMarketDayHigh': 294.7199,
#  'regularMarketDayRange': '288.7 - 294.7199',
#  'regularMarketDayLow': 288.7,
#  'regularMarketVolume': 14036416,
# ...

# %%
si.get_quote_table('aapl')
# Out:
# {'1y Target Est': 176.69,
#  '52 Week Range': '129.04 - 182.94',
#  'Ask': '134.44 x 1000',
#  'Avg. Volume': 87932929.0,
#  'Beta (5Y Monthly)': 1.22,
#  'Bid': '134.40 x 900',
#  "Day's Range": '133.73 - 137.65',
#  'EPS (TTM)': 6.11,
#  'Earnings Date': 'Jan 25, 2023 - Jan 30, 2023',
#  'Ex-Dividend Date': 'Nov 04, 2022',
#  'Forward Dividend & Yield': '0.92 (0.68%)',
#  'Market Cap': '2.14T',
#  'Open': 136.68,
#  'PE Ratio (TTM)': 22.01,
#  'Previous Close': 136.5,
#  'Quote Price': 134.50999450683594,
#  'Volume': 159805707.0}

# %%
si.get_splits("msft")
# Out:
#            splitRatio ticker
# 1987-09-21        2:1   MSFT
# 1990-04-16        2:1   MSFT
# 1991-06-27        3:2   MSFT
# 1992-06-15        3:2   MSFT
# 1994-05-23        2:1   MSFT
# 1996-12-09        2:1   MSFT
# 1998-02-23        2:1   MSFT
# 1999-03-29        2:1   MSFT
# 2003-02-18        2:1   MSFT

# %%
si.get_stats('nflx')
# Out:
#                                          Attribute         Value
# 0                                Beta (5Y Monthly)          1.28
# 1                                 52-Week Change 3       -51.04%
# 2                          S&P500 52-Week Change 3       -15.67%
# 3                                   52 Week High 3        620.61
# 4                                    52 Week Low 3        162.71
# 5                          50-Day Moving Average 3        282.01
# 6                         200-Day Moving Average 3        251.60
# 7                              Avg Vol (3 month) 3        12.22M
# 8                               Avg Vol (10 day) 3        10.52M
# 9                             Shares Outstanding 5       445.02M
# 10                    Implied Shares Outstanding 6           NaN
# 11                                         Float 8       438.94M
# 12                            % Held by Insiders 1         1.44%
# ...

# %%
si.get_stats_valuation('nflx')
# Out:
#                   Unnamed: 0 As of Date: 12/17/2022Current 9/30/2022  \
# 0      Market Cap (intraday)                       129.37B   104.78B
# 1           Enterprise Value                       137.15B   113.19B
# 2               Trailing P/E                         26.03     20.93
# 3                Forward P/E                         26.67     20.12
# 4  PEG Ratio (5 yr expected)                          2.17      2.03
# 5          Price/Sales (ttm)                          4.18      3.44
# 6           Price/Book (mrq)                          6.30      5.49
# 7   Enterprise Value/Revenue                          4.36     14.28
# 8    Enterprise Value/EBITDA                          6.65     20.46
#
#   6/30/2022 3/31/2022 12/31/2021 9/30/2021
# 0    77.77B   166.42B    267.46B   270.35B
# 1    86.29B   175.79B    275.43B   278.20B
# 2     15.87     33.33      54.32     63.25
# 3     16.16     34.25      46.51     47.17
# 4      2.26      1.76       1.48      1.50
# ...

# %%
si.get_top_crypto()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1 Day Chart'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-46e78649e16c> in <module>
# ----> 1 si.get_top_crypto()
#
# ...

# %%
si.get_undervalued_large_caps()
# Out:
#    Symbol                                  Name  Price (Intraday)  Change  \
# 0       F                    Ford Motor Company             12.12   -0.91
# 1    ITUB            Itaú Unibanco Holding S.A.              4.43    0.07
# 2     FCX                 Freeport-McMoRan Inc.             38.36    0.21
# 3     PBR  Petróleo Brasileiro S.A. - Petrobras              9.37   -0.02
# 4    VALE                             Vale S.A.             16.07   -0.33
# ..    ...                                   ...               ...     ...
# 95     EC                        Ecopetrol S.A.              8.94   -0.11
# 96    FOX                       Fox Corporation             28.68   -0.06
# 97      L                     Loews Corporation             55.80   -0.11
# 98   CHTR          Charter Communications, Inc.            304.96   -8.47
# 99   SCCO           Southern Copper Corporation             59.76   -0.13
#
#    % Change    Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)  \
# ...

# %%
tickers = si.tickers_dow()
 
dow_table = si.tickers_dow(True)
dow_table
# Out:
#                      Company Exchange Symbol                        Industry  \
# 0                         3M     NYSE    MMM                    Conglomerate
# 1           American Express     NYSE    AXP              Financial services
# 2                      Amgen   NASDAQ   AMGN               Biopharmaceutical
# 3                      Apple   NASDAQ   AAPL          Information technology
# 4                     Boeing     NYSE     BA           Aerospace and defense
# 5                Caterpillar     NYSE    CAT         Construction and Mining
# 6                    Chevron     NYSE    CVX              Petroleum industry
# 7                      Cisco   NASDAQ   CSCO          Information technology
# 8                  Coca-Cola     NYSE     KO                  Drink industry
# 9                        Dow     NYSE    DOW               Chemical industry
# 10             Goldman Sachs     NYSE     GS              Financial services
# ...

# %%
tickers = si.tickers_ftse100()
si.tickers_ftse100(True)
tickers
# Out:
# ['AAF',
#  'AAL',
#  'ABDN',
#  'ABF',
#  'ADM',
#  'AHT',
#  'ANTO',
#  'AUTO',
#  'AV',
#  'AVV',
#  'AZN',
#  'BA',
#  'BARC',
#  'BATS',
#  'BDEV',
#  'BEZ',
#  'BKG',
#  'BLND',
#  'BME',
#  'BNZL',
#  'BP',
#  'BRBY',
#  'BT-A',
#  'CCH',
#  'CNA',
#  'CPG',
#  'CRDA',
#  'CRH',
#  'CTEC',
#  'DCC',
#  'DGE',
#  'EDV',
#  'ENT',
#  'EXPN',
#  'FCIT',
#  'FLTR',
#  'FRAS',
#  'FRES',
#  'GLEN',
#  'GSK',
#  'HL',
#  'HLMA',
#  'HLN',
#  'HSBA',
#  'HSV',
#  'IAG',
#  'IHG',
#  'III',
#  'IMB',
#  'INF',
#  'ITRK',
#  'JD',
#  'KGF',
#  'LAND',
#  'LGEN',
#  'LLOY',
#  'LSEG',
#  'MNDI',
#  'MNG',
#  'MRO',
#  'NG',
#  'NWG',
#  'NXT',
#  'OCDO',
#  'PHNX',
#  'PRU',
#  'PSH',
#  'PSN',
#  'PSON',
#  'REL',
#  'RIO',
#  'RKT',
#  'RMV',
#  'RR',
#  'RS1',
#  'RTO',
#  'SBRY',
#  'SDR',
#  'SGE',
#  'SGRO',
#  'SHEL',
#  'SKG',
#  'SMDS',
#  'SMIN',
#  'SMT',
#  'SN',
#  'SPX',
#  'SSE',
#  'STAN',
#  'STJ',
#  'SVT',
#  'TSCO',
#  'TW',
#  'ULVR',
#  'UTG',
#  'UU',
#  'VOD',
# ...

# %%
tickers = si.tickers_ftse250()
 
si.tickers_ftse250(True)
tickers
# Out:
# ['3IN',
#  '888',
#  'AGR',
#  'AGT',
#  'AJB',
#  'AML',
#  'APAX',
#  'APEO',
#  'ASC',
#  'ASCL',
#  'ASHM',
#  'ASL',
#  'ATG',
#  'ATST',
#  'ATT',
#  'BAB',
#  'BAG',
#  'BBGI',
#  'BBH',
#  'BBOX',
#  'BBY',
#  'BCG',
#  'BCPT',
#  'BGEO',
#  'BGFD',
#  'BHMG',
#  'BIFF',
#  'BNKR',
#  'BOY',
#  'BPT',
#  'BRSC',
#  'BRWM',
#  'BSIF',
#  'BVIC',
#  'BWY',
#  'BYG',
#  'BYIT',
#  'CAPC',
#  'CBG',
#  'CCC',
#  'CCL',
#  'CCR',
#  'CEY',
#  'CGT',
#  'CHG',
#  'CKN',
#  'CLDN',
#  'CLI',
#  'CMCX',
#  'CNE',
#  'COA',
#  'CRST',
#  'CTY',
#  'CURY',
#  'CWK',
#  'DARK',
#  'DEC',
#  'DGI9',
#  'DLG',
#  'DLN',
#  'DNLM',
#  'DOCS',
#  'DOM',
#  'DPH',
#  'DPLM',
#  'DRX',
#  'DSCV',
#  'EBOX',
#  'EDIN',
#  'ELM',
#  'EMG',
#  'ENOG',
#  'EOT',
#  'ESCT',
#  'ESNT',
#  'EWI',
#  'EZJ',
#  'FAN',
#  'FCSS',
#  'FDM',
#  'FEML',
#  'FEV',
#  'FGP',
#  'FGT',
#  'FOUR',
#  'FSFL',
#  'FSV',
#  'FUTR',
#  'FXPO',
#  'GAW',
#  'GCP',
#  'GEN',
#  'GFTU',
#  'GNS',
#  'GPE',
# ...

# %%
tickers = si.tickers_nasdaq()
 
si.tickers_nasdaq(True)
tickers
# Out:
# ['AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AADI',
#  'AADR',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPB',
#  'AAPD',
#  'AAPL',
#  'AAPU',
#  'AATC',
#  'AAWW',
#  'AAXJ',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABGI',
#  'ABIO',
#  'ABMD',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABST',
#  'ABUS',
#  'ABVC',
#  'ACAB',
#  'ACABU',
#  'ACABW',
#  'ACAC',
#  'ACACU',
#  'ACACW',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACAX',
#  'ACAXR',
#  'ACAXU',
#  'ACAXW',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACCD',
#  'ACDC',
#  'ACDCW',
#  'ACER',
#  'ACET',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACNT',
#  'ACON',
#  'ACONW',
#  'ACOR',
#  'ACQR',
#  'ACQRU',
#  'ACQRW',
#  'ACRS',
#  'ACRV',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACVA',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAL',
#  'ADALU',
#  'ADALW',
#  'ADAP',
#  'ADBE',
#  'ADD',
# ...

# %%
tickers = si.tickers_nifty50()
 
si.tickers_nifty50(True)
tickers
# Out:
# ['ADANIENT.NS',
#  'APOLLOHOSP.NS',
#  'BAJAJ-AUTO.NS',
#  'BAJAJFINSV.NS',
#  'BAJFINANCE.NS',
#  'BHARTIARTL.NS',
#  'BRITANNIA.NS',
#  'CIPLA.NS',
#  'COALINDIA.NS',
#  'HDFCLIFE.NS',
#  'HEROMOTOCO.NS',
#  'HINDALCO.NS',
#  'ICICIBANK.NS',
#  'INDUSINDBK.NS',
#  'ITC.NS',
#  'KOTAKBANK.NS',
#  'LT.NS',
#  'MARUTI.NS',
#  'MM.NS',
#  'NESTLEIND.NS',
#  'NTPC.NS',
#  'ONGC.NS',
#  'RELIANCE.NS',
#  'TATACONSUM.NS',
#  'TATASTEEL.NS',
#  'TCS.NS',
#  'TECHM.NS',
#  'TITAN.NS',
#  'ULTRACEMCO.NS',
#  'WIPRO.NS']

# %%
tickers = si.tickers_niftybank()
tickers
# Out:
# ['AXISBANK',
#  'KOTAKBANK',
#  'HDFCBANK',
#  'SBIN',
#  'BANKBARODA',
#  'INDUSINDBK',
#  'PNB',
#  'IDFCFIRSTB',
#  'ICICIBANK',
#  'RBLBANK',
#  'FEDERALBNK',
#  'BANDHANBNK']

# %%
tickers = si.tickers_other()
 
si.tickers_other(True)
tickers
# Out:
# ['A',
#  'AA',
#  'AAA',
#  'AAAU',
#  'AAC',
#  'AAC.U',
#  'AAC.W',
#  'AAIC',
#  'AAIC$B',
#  'AAIC$C',
#  'AAIN',
#  'AAM$A',
#  'AAM$B',
#  'AAMC',
#  'AAN',
#  'AAP',
#  'AAT',
#  'AAU',
#  'AB',
#  'ABB',
#  'ABBV',
#  'ABC',
#  'ABEQ',
#  'ABEV',
#  'ABG',
#  'ABM',
#  'ABR',
#  'ABR$D',
#  'ABR$E',
#  'ABR$F',
#  'ABT',
#  'AC',
#  'ACA',
#  'ACAQ',
#  'ACAQ.U',
#  'ACAQ.W',
#  'ACCO',
#  'ACDI',
#  'ACDI.U',
#  'ACDI.W',
#  'ACEL',
#  'ACES',
#  'ACHR',
#  'ACHR.W',
#  'ACI',
#  'ACIO',
#  'ACM',
#  'ACN',
#  'ACP',
#  'ACP$A',
#  'ACR',
#  'ACR$C',
#  'ACR$D',
#  'ACRE',
#  'ACRO',
#  'ACRO.U',
#  'ACRO.W',
#  'ACSI',
#  'ACTV',
#  'ACU',
#  'ACV',
#  'ACVF',
#  'ACWF',
#  'ACWV',
#  'ADC',
#  'ADC$A',
#  'ADCT',
#  'ADEX',
#  'ADEX.U',
#  'ADEX.W',
#  'ADFI',
#  'ADIV',
#  'ADM',
#  'ADME',
#  'ADNT',
#  'ADPV',
#  'ADRA',
#  'ADRA.U',
#  'ADRA.W',
#  'ADRT',
#  'ADRT.U',
#  'ADT',
#  'ADX',
#  'AE',
#  'AEE',
#  'AEF',
#  'AEFC',
#  'AEG',
#  'AEL',
#  'AEL$A',
# ...

# %%
tickers = si.tickers_sp500()
 
si.tickers_sp500(True)
tickers
# Out:
# ['A',
#  'AAL',
#  'AAP',
#  'AAPL',
#  'ABBV',
#  'ABC',
#  'ABMD',
#  'ABT',
#  'ACGL',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALK',
#  'ALL',
#  'ALLE',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'ANSS',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APTV',
#  'ARE',
#  'ATO',
#  'ATVI',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BALL',
#  'BAX',
#  'BBWI',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BF-B',
#  'BIIB',
#  'BIO',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLK',
#  'BMY',
#  'BR',
#  'BRK-B',
#  'BRO',
#  'BSX',
#  'BWA',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDAY',
#  'CDNS',
#  'CDW',
#  'CE',
#  'CEG',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
# ...
